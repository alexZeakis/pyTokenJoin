# %% [markdown]
# # Load data

# %%
import pandas as pd

file = '../data/yelp_sample.csv'

delta = 0.7

df = pd.read_csv(file, header=None, nrows=1000)
df = df.reset_index(drop=False)
df.columns = ['id', 'text']
df.text = df.text.apply(lambda x: x.split(';'))
df.text = df.text.apply(lambda x: list(set(x)))
df
# Out:
#       id                                               text
# 0      0  [bar, american, gardens, traditional, nightlif...
# 1      1  [delis, soup, cafes, salad, vegetarian, sandwi...
# 2      2  [antiques, used, vintage, consignment, fashion...
# 3      3                       [beauty, salons, hair, spas]
# 4      4  [life, gyms, instruction, training, fitness, a...
# ..   ...                                                ...
# 995  995  [services, southern, event, caterers, barbeque...
# 996  996  [repair, automotive, parts, car, supplies, aut...
# 997  997  [beauty, health, massage, spas, medical, therapy]
# 998  998            [entertainment, bars, nightlife, adult]
# 999  999                       [beauty, salons, nail, spas]
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Self Join with Threshold

# %% [markdown]
# ## Jaccard Self Join

# %%
from pyTokenJoin.jaccard.jaccard_delta import JaccardTokenJoin
from pyTokenJoin.edit.edit_delta import EditTokenJoin

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_self(df, id='id', join='text', posFilter=True, jointFilter=True)
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Progress 900/1,000
# Time elapsed: Init: 0.01, Cand Gen: 0.04, Cand Ref: 0.02, Cand Ver: 0.05
# Candidates Generated: 11,628, Refined: 4,577, Verified: 1,619, Survived: 1,615
#       l_id  r_id     score                                             l_text  \
# 0        5   376  1.000000                                [restaurants, thai]
# 1        5   700  1.000000                                [restaurants, thai]
# 2       47   138  1.000000                              [restaurants, indian]
# 3       47   277  1.000000                              [restaurants, indian]
# 4       47   308  1.000000                              [restaurants, indian]
# ...    ...   ...       ...                                                ...
# 1610   866   949  0.785714  [beauty, salons, service, nail, hair, skin, ey...
# 1611   987   635  0.785714  [beauty, yoga, life, health, massage, instruct...
# 1612   993    70  0.714286  [beauty, service, hair, skin, massage, laser, ...
# 1613   451   707  0.923077  [beauty, hair, skin, health, laser, doctors, s...
# 1614    70   949  0.800000  [beauty, service, salons, nail, hair, skin, ma...
#
#                                                  r_text
# 0                                   [restaurants, thai]
# 1                                   [restaurants, thai]
# 2                                 [restaurants, indian]
# 3                                 [restaurants, indian]
# 4                                 [restaurants, indian]
# ...                                                 ...
# 1610  [makeup, service, salons, beauty, nail, hair, ...
# 1611  [beauty, accessories, yoga, life, health, fash...
# 1612  [beauty, service, salons, nail, hair, skin, ma...
# 1613  [beauty, hair, skin, health, laser, doctors, s...
# 1614  [makeup, service, salons, beauty, nail, hair, ...
#
# [1615 rows x 5 columns]

# %% [markdown]
# ## Edit Self Join

# %%
output_df_2 = EditTokenJoin().tokenjoin_self(df, id='id', join='text', posFilter=True, jointFilter=True)
output_df_2
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Progress 900/1,000
# Time elapsed: Init: 0.01, Cand Gen: 0.10, Cand Ref: 0.07, Cand Ver: 0.50
# Candidates Generated: 51,163, Refined: 14,726, Verified: 6,097, Survived: 2,056
#       l_id  r_id     score                                             l_text  \
# 0        5   376  1.000000                                [restaurants, thai]
# 1        5   700  1.000000                                [restaurants, thai]
# 2       47   138  1.000000                              [restaurants, indian]
# 3       47   277  1.000000                              [restaurants, indian]
# 4       47   308  1.000000                              [restaurants, indian]
# ...    ...   ...       ...                                                ...
# 2051   993    70  0.756098  [beauty, service, hair, skin, massage, laser, ...
# 2052   451   707  0.923077  [beauty, hair, skin, health, laser, doctors, s...
# 2053   451   473  0.714286  [beauty, hair, skin, health, laser, doctors, s...
# 2054    70   949  0.820225  [beauty, service, salons, nail, hair, skin, ma...
# 2055   665   940  0.716621  [nutritionists, life, health, loss, gyms, inst...
#
#                                                  r_text
# 0                                   [restaurants, thai]
# 1                                   [restaurants, thai]
# 2                                 [restaurants, indian]
# 3                                 [restaurants, indian]
# 4                                 [restaurants, indian]
# ...                                                 ...
# 2051  [beauty, service, salons, nail, hair, skin, ma...
# 2052  [beauty, hair, skin, health, laser, doctors, s...
# 2053  [beauty, hair, skin, health, laser, spas, cont...
# 2054  [makeup, service, salons, beauty, nail, hair, ...
# 2055  [life, health, loss, massage, trainers, instru...
#
# [2056 rows x 5 columns]

# %% [markdown]
# ## Compare

# %%
output_df = output_df_2.copy()
output_df['edit_score'] = output_df['score']
output_df = output_df.set_index(['l_id', 'r_id'])
output_df['jaccard_score'] = output_df_1.set_index(['l_id', 'r_id'])['score']
output_df = output_df.reset_index(drop=False)
output_df = output_df.drop('score', axis=1)
output_df
# Out:
#       l_id  r_id                                             l_text  \
# 0        5   376                                [restaurants, thai]
# 1        5   700                                [restaurants, thai]
# 2       47   138                              [restaurants, indian]
# 3       47   277                              [restaurants, indian]
# 4       47   308                              [restaurants, indian]
# ...    ...   ...                                                ...
# 2051   993    70  [beauty, service, hair, skin, massage, laser, ...
# 2052   451   707  [beauty, hair, skin, health, laser, doctors, s...
# 2053   451   473  [beauty, hair, skin, health, laser, doctors, s...
# 2054    70   949  [beauty, service, salons, nail, hair, skin, ma...
# 2055   665   940  [nutritionists, life, health, loss, gyms, inst...
#
#                                                  r_text  edit_score  \
# 0                                   [restaurants, thai]    1.000000
# 1                                   [restaurants, thai]    1.000000
# 2                                 [restaurants, indian]    1.000000
# 3                                 [restaurants, indian]    1.000000
# 4                                 [restaurants, indian]    1.000000
# ...                                                 ...         ...
# 2051  [beauty, service, salons, nail, hair, skin, ma...    0.756098
# 2052  [beauty, hair, skin, health, laser, doctors, s...    0.923077
# 2053  [beauty, hair, skin, health, laser, spas, cont...    0.714286
# 2054  [makeup, service, salons, beauty, nail, hair, ...    0.820225
# 2055  [life, health, loss, massage, trainers, instru...    0.716621
#
#       jaccard_score
# 0          1.000000
# 1          1.000000
# 2          1.000000
# 3          1.000000
# 4          1.000000
# ...             ...
# 2051       0.714286
# 2052       0.923077
# 2053            NaN
# 2054       0.800000
# 2055            NaN
#
# [2056 rows x 6 columns]

# %%
output_df.loc[output_df.jaccard_score.isna()].head()
# Out:
#      l_id  r_id                  l_text                  r_text  edit_score  \
# 54    158   578  [restaurants, mexican]  [restaurants, african]    0.714286
# 90    310   578  [restaurants, mexican]  [restaurants, african]    0.714286
# 126   578   639  [restaurants, african]  [restaurants, mexican]    0.714286
# 127   578   646  [restaurants, african]  [restaurants, mexican]    0.714286
# 128   578   658  [restaurants, african]  [restaurants, mexican]    0.714286
#
#      jaccard_score
# 54             NaN
# 90             NaN
# 126            NaN
# 127            NaN
# 128            NaN

# %%
output_df.loc[(output_df.jaccard_score != output_df.edit_score) & (output_df.jaccard_score < 1.0)].head()
# Out:
#       l_id  r_id                                      l_text  \
# 516    145   274  [doctors, dermatologists, health, medical]
# 517    145   411  [doctors, dermatologists, health, medical]
# 690    274   411      [doctors, health, medical, otologists]
# 1247   115   922  [real, estate, services, home, apartments]
# 1271   153   922  [real, estate, services, home, apartments]
#
#                                             r_text  edit_score  jaccard_score
# 516         [doctors, health, medical, otologists]    0.818182       0.791045
# 517   [doctors, health, ophthalmologists, medical]    0.800000       0.708738
# 690   [doctors, health, ophthalmologists, medical]    0.846154       0.756098
# 1247        [real, agents, estate, services, home]    0.791045       0.714286
# 1271        [real, agents, estate, services, home]    0.791045       0.714286

# %% [markdown]
# # Foreign Join with Threshold

# %%
df2 = df.sample(1000, random_state=1924).reset_index(drop=True)
df1 = df.sample(100, random_state=1924).reset_index(drop=True)

# %% [markdown]
# ## Jaccard Foreign Join

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text',
                              posFilter=True, jointFilter=True)
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100
# Time elapsed: Init: 0.01, Cand Gen: 0.02, Cand Ref: 0.01, Cand Ver: 0.01
# Candidates Generated: 8,442, Refined: 1,284, Verified: 438, Survived: 435
#      l_id  r_id  score                                             l_text  \
# 0     751   751    1.0                          [restaurants, vietnamese]
# 1     727   727    1.0                             [burgers, restaurants]
# 2      51   688    1.0                             [restaurants, italian]
# 3      51   463    1.0                             [restaurants, italian]
# 4      51    51    1.0                             [restaurants, italian]
# ..    ...   ...    ...                                                ...
# 430   846   846    1.0  [wine, new, american, traditional, nightlife, ...
# 431   867   867    1.0  [new, breakfast, american, cream, burgers, tra...
# 432   176   176    1.0  [design, accessories, services, home, jewelry,...
# 433   531   531    1.0  [parks, party, local, trampoline, courses, ser...
# 434   982   982    1.0  [makeup, salons, mens, extensions, beauty, hai...
#
#                                                 r_text
# 0                            [restaurants, vietnamese]
# 1                               [burgers, restaurants]
# 2                               [restaurants, italian]
# 3                               [restaurants, italian]
# 4                               [restaurants, italian]
# ..                                                 ...
# 430  [wine, new, american, traditional, nightlife, ...
# 431  [new, breakfast, american, cream, burgers, tra...
# 432  [design, accessories, services, home, jewelry,...
# 433  [parks, party, local, trampoline, courses, ser...
# 434  [makeup, salons, mens, extensions, beauty, hai...
#
# [435 rows x 5 columns]

# %% [markdown]
# ## Edit Foreign Join

# %%
output_df_2 = EditTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text',
                              posFilter=True, jointFilter=True)
output_df_2
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100
# Time elapsed: Init: 0.02, Cand Gen: 0.05, Cand Ref: 0.04, Cand Ver: 0.22
# Candidates Generated: 25,939, Refined: 5,813, Verified: 1,944, Survived: 587
#      l_id  r_id  score                                             l_text  \
# 0     751   751    1.0                          [restaurants, vietnamese]
# 1     727   727    1.0                             [burgers, restaurants]
# 2      51   688    1.0                             [restaurants, italian]
# 3      51   463    1.0                             [restaurants, italian]
# 4      51    51    1.0                             [restaurants, italian]
# ..    ...   ...    ...                                                ...
# 582   846   846    1.0  [wine, new, american, traditional, nightlife, ...
# 583   867   867    1.0  [new, breakfast, american, cream, burgers, tra...
# 584   176   176    1.0  [design, accessories, services, home, jewelry,...
# 585   531   531    1.0  [parks, party, local, trampoline, courses, ser...
# 586   982   982    1.0  [makeup, salons, mens, extensions, beauty, hai...
#
#                                                 r_text
# 0                            [restaurants, vietnamese]
# 1                               [burgers, restaurants]
# 2                               [restaurants, italian]
# 3                               [restaurants, italian]
# 4                               [restaurants, italian]
# ..                                                 ...
# 582  [wine, new, american, traditional, nightlife, ...
# 583  [new, breakfast, american, cream, burgers, tra...
# 584  [design, accessories, services, home, jewelry,...
# 585  [parks, party, local, trampoline, courses, ser...
# 586  [makeup, salons, mens, extensions, beauty, hai...
#
# [587 rows x 5 columns]

# %% [markdown]
# # Foreign Jaccard Join with k

# %%
from pyTokenJoin.jaccard.jaccard_topk import JaccardTokenJoin

# %%
df2 = df.sample(1000, random_state=1924).reset_index(drop=True)
df1 = df.sample(100, random_state=1924).reset_index(drop=True)

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text')
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100 	: δ: 1e-09
# Time elapsed: Init: 0.01, Cand Gen: 0.07, Cand Ref: 0.18, Cand Ver: 0.95
# Candidates Generated: 34,185, Refined: 8,210, Verified: 5,002, Survived: 4,699
# Final δ is 0.500
#         score  l_id  r_id                                             l_text  \
# 750  0.909091   836   303  [orthodontists, general, health, surgeons, per...
# 587  0.875000   884   749  [endodontists, general, health, medical, denti...
# 722  0.875000   311   939  [repair, automotive, parts, car, supplies, aut...
# 788  0.875000   338   615     [beauty, salons, nail, hair, skin, spas, care]
# 799  0.857143   338   172     [beauty, salons, nail, hair, skin, spas, care]
# ..        ...   ...   ...                                                ...
# 184  0.500000    65   218  [tex-mex, mexican, coffee, restaurants, food, ...
# 183  0.500000   420   232  [new, american, italian, pizza, sandwiches, re...
# 182  0.500000   705   138  [restaurants, indian, himalayan/nepalese, chin...
# 181  0.500000   705   974  [restaurants, indian, himalayan/nepalese, chin...
# 500  0.500000    65   933  [tex-mex, mexican, coffee, restaurants, food, ...
#
#                                                 r_text
# 750  [general, health, surgeons, periodontists, med...
# 587  [dentists, endodontists, orthodontists, genera...
# 722  [used, repair, automotive, car, parts, supplie...
# 788  [beauty, salons, nail, hair, skin, spas, care,...
# 799           [beauty, salons, nail, skin, spas, care]
# ..                                                 ...
# 184    [burgers, fast, coffee, restaurants, food, tea]
# 183                      [restaurants, pizza, italian]
# 182                              [restaurants, indian]
# 181                             [restaurants, chinese]
# 500                                [food, tea, coffee]
#
# [1000 rows x 5 columns]
