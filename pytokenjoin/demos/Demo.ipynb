# %% [markdown]
# # Load data

# %%
import pandas as pd

file = '../data/yelp_sample.csv'

delta = 0.7

df = pd.read_csv(file, header=None, nrows=1000)
df = df.reset_index(drop=False)
df.columns = ['id', 'text']
df.text = df.text.apply(lambda x: x.split(';'))
df.text = df.text.apply(lambda x: list(set(x)))
df
# Out:
#       id                                               text
# 0      0  [restaurants, traditional, bar, gardens, night...
# 1      1  [restaurants, delis, sandwiches, vegetarian, s...
# 2      2  [home, antiques, fashion, used, consignment, v...
# 3      3                       [salons, spas, beauty, hair]
# 4      4  [interval, life, instruction, active, training...
# ..   ...                                                ...
# 995  995  [restaurants, barbeque, caterers, southern, pl...
# 996  996  [supplies, repair, dealers, parts, automotive,...
# 997  997  [health, beauty, therapy, medical, massage, spas]
# 998  998            [bars, entertainment, nightlife, adult]
# 999  999                       [salons, nail, spas, beauty]
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Self Join with Threshold

# %% [markdown]
# ## Jaccard Self Join

# %%
from pytokenjoin.jaccard.join_delta import JaccardTokenJoin
from pytokenjoin.edit.join_delta import EditTokenJoin

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_self(df, id='id', join='text', posFilter=True, jointFilter=True)
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Progress 900/1,000
# Time elapsed: Init: 0.01, Cand Gen: 0.04, Cand Ref: 0.02, Cand Ver: 0.07
# Candidates Generated: 11,631, Refined: 4,579, Verified: 1,619, Survived: 1,615
#       l_id  r_id     score                                             l_text  \
# 0        5   376  1.000000                                [restaurants, thai]
# 1        5   700  1.000000                                [restaurants, thai]
# 2       47   138  1.000000                              [indian, restaurants]
# 3       47   277  1.000000                              [indian, restaurants]
# 4       47   308  1.000000                              [indian, restaurants]
# ...    ...   ...       ...                                                ...
# 1610   866   949  0.785714  [salons, nail, service, beauty, care, waxing, ...
# 1611   987   635  0.785714  [health, beauty, spas, instruction, therapy, l...
# 1612   993    70  0.714286  [service, beauty, care, laser, eyelash, massag...
# 1613   451   707  0.923077  [doctors, health, beauty, care, cosmetic, lase...
# 1614    70   949  0.800000  [service, nail, salons, care, beauty, waxing, ...
#
#                                                  r_text
# 0                                   [restaurants, thai]
# 1                                   [restaurants, thai]
# 2                                 [indian, restaurants]
# 3                                 [restaurants, indian]
# 4                                 [restaurants, indian]
# ...                                                 ...
# 1610  [makeup, service, nail, salons, care, beauty, ...
# 1611  [health, beauty, spas, instruction, therapy, l...
# 1612  [service, nail, salons, care, beauty, waxing, ...
# 1613  [doctors, plastic, health, beauty, care, cosme...
# 1614  [makeup, service, nail, salons, care, beauty, ...
#
# [1615 rows x 5 columns]

# %% [markdown]
# ## Edit Self Join

# %%
output_df_2 = EditTokenJoin().tokenjoin_self(df, id='id', join='text', posFilter=True, jointFilter=True)
output_df_2
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Progress 900/1,000
# Time elapsed: Init: 0.01, Cand Gen: 0.10, Cand Ref: 0.07, Cand Ver: 0.53
# Candidates Generated: 51,162, Refined: 14,726, Verified: 6,097, Survived: 2,056
#       l_id  r_id     score                                             l_text  \
# 0        5   376  1.000000                                [restaurants, thai]
# 1        5   700  1.000000                                [restaurants, thai]
# 2       47   138  1.000000                              [indian, restaurants]
# 3       47   277  1.000000                              [indian, restaurants]
# 4       47   308  1.000000                              [indian, restaurants]
# ...    ...   ...       ...                                                ...
# 2051   993    70  0.756098  [service, beauty, care, laser, eyelash, massag...
# 2052   451   707  0.923077  [doctors, health, beauty, care, cosmetic, lase...
# 2053   451   473  0.714286  [doctors, health, beauty, care, cosmetic, lase...
# 2054    70   949  0.820225  [service, nail, salons, care, beauty, waxing, ...
# 2055   665   940  0.716621  [nutritionists, health, instruction, life, int...
#
#                                                  r_text
# 0                                   [restaurants, thai]
# 1                                   [restaurants, thai]
# 2                                 [indian, restaurants]
# 3                                 [restaurants, indian]
# 4                                 [restaurants, indian]
# ...                                                 ...
# 2051  [service, nail, salons, care, beauty, waxing, ...
# 2052  [doctors, plastic, health, beauty, care, cosme...
# 2053  [health, contouring, care, beauty, medical, la...
# 2054  [makeup, service, nail, salons, care, beauty, ...
# 2055  [health, instruction, therapy, life, medical, ...
#
# [2056 rows x 5 columns]

# %% [markdown]
# ## Compare

# %%
output_df = output_df_2.copy()
output_df['edit_score'] = output_df['score']
output_df = output_df.set_index(['l_id', 'r_id'])
output_df['jaccard_score'] = output_df_1.set_index(['l_id', 'r_id'])['score']
output_df = output_df.reset_index(drop=False)
output_df = output_df.drop('score', axis=1)
output_df
# Out:
#       l_id  r_id                                             l_text  \
# 0        5   376                                [restaurants, thai]
# 1        5   700                                [restaurants, thai]
# 2       47   138                              [indian, restaurants]
# 3       47   277                              [indian, restaurants]
# 4       47   308                              [indian, restaurants]
# ...    ...   ...                                                ...
# 2051   993    70  [service, beauty, care, laser, eyelash, massag...
# 2052   451   707  [doctors, health, beauty, care, cosmetic, lase...
# 2053   451   473  [doctors, health, beauty, care, cosmetic, lase...
# 2054    70   949  [service, nail, salons, care, beauty, waxing, ...
# 2055   665   940  [nutritionists, health, instruction, life, int...
#
#                                                  r_text  edit_score  \
# 0                                   [restaurants, thai]    1.000000
# 1                                   [restaurants, thai]    1.000000
# 2                                 [indian, restaurants]    1.000000
# 3                                 [restaurants, indian]    1.000000
# 4                                 [restaurants, indian]    1.000000
# ...                                                 ...         ...
# 2051  [service, nail, salons, care, beauty, waxing, ...    0.756098
# 2052  [doctors, plastic, health, beauty, care, cosme...    0.923077
# 2053  [health, contouring, care, beauty, medical, la...    0.714286
# 2054  [makeup, service, nail, salons, care, beauty, ...    0.820225
# 2055  [health, instruction, therapy, life, medical, ...    0.716621
#
#       jaccard_score
# 0          1.000000
# 1          1.000000
# 2          1.000000
# 3          1.000000
# 4          1.000000
# ...             ...
# 2051       0.714286
# 2052       0.923077
# 2053            NaN
# 2054       0.800000
# 2055            NaN
#
# [2056 rows x 6 columns]

# %%
output_df.loc[output_df.jaccard_score.isna()].head()
# Out:
#      l_id  r_id                  l_text                  r_text  edit_score  \
# 54    158   578  [restaurants, mexican]  [african, restaurants]    0.714286
# 90    310   578  [restaurants, mexican]  [african, restaurants]    0.714286
# 126   578   639  [african, restaurants]  [restaurants, mexican]    0.714286
# 127   578   646  [african, restaurants]  [restaurants, mexican]    0.714286
# 128   578   658  [african, restaurants]  [restaurants, mexican]    0.714286
#
#      jaccard_score
# 54             NaN
# 90             NaN
# 126            NaN
# 127            NaN
# 128            NaN

# %%
output_df.loc[(output_df.jaccard_score != output_df.edit_score) & (output_df.jaccard_score < 1.0)].head()
# Out:
#       l_id  r_id                                      l_text  \
# 516    145   274  [doctors, health, dermatologists, medical]
# 517    145   411  [doctors, health, dermatologists, medical]
# 690    274   411      [doctors, health, medical, otologists]
# 1247   115   922  [home, real, estate, apartments, services]
# 1271   153   922  [home, real, estate, apartments, services]
#
#                                             r_text  edit_score  jaccard_score
# 516         [doctors, health, medical, otologists]    0.818182       0.791045
# 517   [doctors, health, medical, ophthalmologists]    0.800000       0.708738
# 690   [doctors, health, medical, ophthalmologists]    0.846154       0.756098
# 1247        [home, real, agents, estate, services]    0.791045       0.714286
# 1271        [home, real, agents, estate, services]    0.791045       0.714286

# %% [markdown]
# # Foreign Join with Threshold

# %%
df2 = df.sample(1000, random_state=1924).reset_index(drop=True)
df1 = df.sample(100, random_state=1924).reset_index(drop=True)

# %% [markdown]
# ## Jaccard Foreign Join

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text',
                              posFilter=True, jointFilter=True)
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100
# Time elapsed: Init: 0.01, Cand Gen: 0.02, Cand Ref: 0.01, Cand Ver: 0.02
# Candidates Generated: 8,158, Refined: 1,276, Verified: 437, Survived: 435
#      l_id  r_id  score                                             l_text  \
# 0     751   751    1.0                          [restaurants, vietnamese]
# 1     727   727    1.0                             [restaurants, burgers]
# 2      51   688    1.0                             [restaurants, italian]
# 3      51   463    1.0                             [restaurants, italian]
# 4      51    51    1.0                             [restaurants, italian]
# ..    ...   ...    ...                                                ...
# 430   846   846    1.0  [restaurants, traditional, american, new, nigh...
# 431   867   867    1.0  [restaurants, traditional, breakfast, yogurt, ...
# 432   176   176    1.0  [decor, jewelry, home, design, gifts, fashion,...
# 433   531   531    1.0  [event, supplies, care, party, life, child, lo...
# 434   982   982    1.0  [makeup, salons, services, beauty, waxing, sty...
#
#                                                 r_text
# 0                            [restaurants, vietnamese]
# 1                               [restaurants, burgers]
# 2                               [restaurants, italian]
# 3                               [restaurants, italian]
# 4                               [restaurants, italian]
# ..                                                 ...
# 430  [restaurants, traditional, american, new, nigh...
# 431  [restaurants, traditional, breakfast, yogurt, ...
# 432  [decor, jewelry, home, design, gifts, fashion,...
# 433  [event, supplies, care, party, life, child, lo...
# 434  [makeup, salons, services, beauty, waxing, sty...
#
# [435 rows x 5 columns]

# %% [markdown]
# ## Edit Foreign Join

# %%
output_df_2 = EditTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text',
                              posFilter=True, jointFilter=True)
output_df_2
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100
# Time elapsed: Init: 0.02, Cand Gen: 0.04, Cand Ref: 0.03, Cand Ver: 0.22
# Candidates Generated: 25,939, Refined: 5,747, Verified: 1,885, Survived: 587
#      l_id  r_id  score                                             l_text  \
# 0     751   751    1.0                          [restaurants, vietnamese]
# 1     727   727    1.0                             [restaurants, burgers]
# 2      51   688    1.0                             [restaurants, italian]
# 3      51   463    1.0                             [restaurants, italian]
# 4      51    51    1.0                             [restaurants, italian]
# ..    ...   ...    ...                                                ...
# 582   846   846    1.0  [restaurants, traditional, american, new, nigh...
# 583   867   867    1.0  [restaurants, traditional, breakfast, yogurt, ...
# 584   176   176    1.0  [decor, jewelry, home, design, gifts, fashion,...
# 585   531   531    1.0  [event, supplies, care, party, life, child, lo...
# 586   982   982    1.0  [makeup, salons, services, beauty, waxing, sty...
#
#                                                 r_text
# 0                            [restaurants, vietnamese]
# 1                               [restaurants, burgers]
# 2                               [restaurants, italian]
# 3                               [restaurants, italian]
# 4                               [restaurants, italian]
# ..                                                 ...
# 582  [restaurants, traditional, american, new, nigh...
# 583  [restaurants, traditional, breakfast, yogurt, ...
# 584  [decor, jewelry, home, design, gifts, fashion,...
# 585  [event, supplies, care, party, life, child, lo...
# 586  [makeup, salons, services, beauty, waxing, sty...
#
# [587 rows x 5 columns]

# %% [markdown]
# # Foreign Jaccard Join with k

# %%
from pytokenjoin.jaccard.jaccard_topk import JaccardTokenJoin

# %%
df2 = df.sample(1000, random_state=1924).reset_index(drop=True)
df1 = df.sample(100, random_state=1924).reset_index(drop=True)

# %%
output_df_1 = JaccardTokenJoin().tokenjoin_foreign(df1, df2, 'id', 'id', 'text', 'text')
output_df_1
# Out:
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 1000. Elements per set: 6.293. Tokens per Element: 5.95741299856984
# Finished reading file. Lines read: 0. Lines skipped due to errors: 0. Num of sets: 100. Elements per set: 6.28. Tokens per Element: 5.843949044585988
# Progress 0/100 	: δ: 1e-09
# Time elapsed: Init: 0.01, Cand Gen: 0.07, Cand Ref: 0.17, Cand Ver: 1.04
# Candidates Generated: 34,018, Refined: 8,170, Verified: 4,973, Survived: 4,669
# Final δ is 0.500
#         score  l_id  r_id                                             l_text  \
# 766  0.909091   836   303  [health, general, orthodontists, cosmetic, den...
# 519  0.875000   338   615     [salons, nail, beauty, care, skin, hair, spas]
# 561  0.875000   884   749  [health, general, endodontists, cosmetic, medi...
# 692  0.875000   311   939  [supplies, repair, dealers, parts, automotive,...
# 999  0.857143   844   906  [health, general, cosmetic, dentistry, dentist...
# ..        ...   ...   ...                                                ...
# 106  0.500000   369   532  [restaurants, american, nightlife, new, bars, ...
# 107  0.500000   793   603                                [coffee, tea, food]
# 108  0.500000   409   592  [canadian, restaurants, cocktail, nightlife, s...
# 109  0.500000   893   949  [salons, nail, beauty, care, massage, skin, spas]
# 0    0.500000   243   859                    [health, medical, optometrists]
#
#                                                 r_text
# 766  [health, general, cosmetic, dentistry, medical...
# 519  [salons, nail, beauty, care, removal, skin, ha...
# 561  [health, general, orthodontists, endodontists,...
# 692  [supplies, repair, dealers, parts, used, autom...
# 999  [health, general, cosmetic, dentistry, dentist...
# ..                                                 ...
# 106  [restaurants, traditional, nightlife, bars, sp...
# 107  [restaurants, mexican, coffee, bakeries, tea, ...
# 108  [canadian, restaurants, nightlife, plates, new...
# 109  [makeup, service, nail, salons, care, beauty, ...
# 0                           [health, medical, centers]
#
# [1000 rows x 5 columns]
